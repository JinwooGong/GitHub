# %% [markdown]
# # 신경 단어 벡터 시각화를 사용해 고차원의 단어를 2차원으로 시각화
# 고차원 공간의 단어를 2차원 공간에 시각화하기 위해 DNN을 사용한다.

# %%
from __future__ import print_function

import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
from nltk.stem import PorterStemmer
import string
import numpy as np
import pandas as pd
import random
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import matplotlib.pyplot as plt
def preprocessing(text):
    text2 = " ".join("".join([" " if ch in string.punctuation else ch for ch in text]).split())
    
    tokens = [word for sent in nltk.sent_tokenize(text2) for word in nltk.word_tokenize(sent)]
    tokens = [word.lower() for word in tokens]
    
    stopwds = stopwords.words('english')
    tokens = [token for token in tokens if token not in stopwds]
    tokens = [word for word in tokens if len(word)>=3]
    stemmer = PorterStemmer()
    
    tokens = [stemmer.stem(word) for word in tokens]
    
    tagged_corpus = pos_tag(tokens)
    
    Noun_tags = ['NN','NNP','NNPS','NNS']
    Verb_tags = ['VB','VBD','VBG','VBN','VBP','VBZ']

    lemmatizer = WordNetLemmatizer()

    def prat_lemmatize(token,tag):
        if tag in Noun_tags:
            return lemmatizer.lemmatize(token,'n')
        elif tag in Verb_tags:
            return lemmatizer.lemmatize(token,'v')
        else:
            return lemmatizer.lemmatize(token,'n')
        
    pre_proc_text = " ".join([prat_lemmatize(token,tag) for token,tag in tagged_corpus])

    return pre_proc_text

# %%
fin = open("alice_in_wonderland.txt", "rb")

# %%
lines = []

for line in fin:
    line = line.strip().decode("ascii", "ignore")
    
    if len(line) == 0:
        continue
        
    lines.append(preprocessing(line))

# %%
fin.close()

# %%
lines
# Out:
# ['alic adventur wonderland',
#  'alic adventur wonderland',
#  'lewi carrol',
#  'millennium fulcrum edit',
#  'chapter',
#  'rabbit hole',
#  'alic begin get tire sit sister',
#  'bank noth twice',
#  'peep book sister read',
#  'pictur convers use book',
#  'think alic without pictur convers',
#  'consid mind well could',
#  'hot day make feel sleepi stupid whether',
#  'pleasur make daisi chain would worth troubl',
#  'get pick daisi suddenli white',
#  'rabbit pink eye run close',
#  'noth remark alic',
#  'think much way hear rabbit say',
#  'dear dear shall late think',
#  'afterward occur ought',
#  'wonder time seem quit natur',
#  'rabbit actual take watch waistcoat',
#  'pocket look hurri alic start',
#  'foot flash across mind never',
#  'see rabbit either waistcoat pocket watch',
#  'take burn curio run across',
#  'field fortun time see pop',
#  'larg rabbit hole hedg',
#  'anoth moment go alic never',
#  'consid world get',
#  'rabbit hole go straight like tunnel way',
#  'dip suddenli suddenli alic',
#  'moment think stop found',
#  'fall deep well',
#  'either well deep fell slowli',
#  'plenti time go look',
#  'wonder go happen next first tri look',
#  'make come dark',
#  'see anyth look side well',
#  'notic fill cupboard book shelv',
#  'saw map pictur hung upon peg',
#  'take jar one shelv pas',
#  'label orang marmalad great disappoint',
#  'empti like drop jar fear kill',
#  'somebodi manag put one cupboard',
#  'fell past',
#  'well think alic fall',
#  'shall think noth tumbl stair brave',
#  'think home say anyth',
#  'even fell top hous like',
#  'true',
#  'would fall never come end',
#  'wonder mani mile fall time say aloud',
#  'must get somewher near centr earth let',
#  'see would four thousand mile think',
#  'see alic learnt sever thing sort',
#  'lesson schoolroom though good',
#  'opportun show knowledg one',
#  'listen still good practic say ye',
#  'right distanc wonder latitud',
#  'longitud get alic idea latitud',
#  'longitud either thought nice grand word',
#  'say',
#  'present begin wonder shall fall right',
#  'earth funni seem come among',
#  'peopl walk head downward antipathi',
#  'think rather glad one listen',
#  'time sound right word shall',
#  'ask name countri know',
#  'plea new zealand australia tri',
#  'curtsey speak fanci curtsey fall',
#  'air think could manag',
#  'ignor littl girl think ask',
#  'never ask perhap shall see write somewher',
#  'noth el alic soon',
#  'begin talk dinah miss much night',
#  'think dinah cat hope rememb',
#  'saucer milk tea time dinah dear wish',
#  'mouse air afraid',
#  'might catch bat like mous know',
#  'cat eat bat wonder alic begin get',
#  'rather sleepi go say dreami sort',
#  'way cat eat bat cat eat bat sometim',
#  'bat eat cat see answer either',
#  'question much matter way put felt',
#  'doze begin dream',
#  'walk hand hand dinah say',
#  'earnestli dinah tell truth ever eat',
#  'bat suddenli thump thump come upon heap',
#  'stick dri leav fall',
#  'alic bit hurt jump foot',
#  'moment look dark overhead',
#  'anoth long passag white rabbit still',
#  'sight hurri moment lose',
#  'away go alic like wind time hear',
#  'say turn corner ear whisker late',
#  'get close behind turn',
#  'corner rabbit longer see found',
#  'long low hall lit row lamp',
#  'hang roof',
#  'door round hall lock',
#  'alic way one side',
#  'tri everi door walk sadli middl',
#  'wonder ever get',
#  'suddenli come upon littl three leg tabl make',
#  'solid glass noth except tini golden key',
#  'alic first think might belong one',
#  'door hall ala either lock larg',
#  'key small rate would open',
#  'howev second time round come upon low',
#  'curtain notic behind littl',
#  'door fifteen inch high tri littl golden key',
#  'lock great delight fit',
#  'alic open door find lead small',
#  'passag much larger rat hole knelt',
#  'look along passag loveliest garden ever saw',
#  'long get dark hall wander',
#  'among bed bright flower cool fountain',
#  'could even get head doorway even',
#  'head would think poor alic would',
#  'littl use without shoulder wish',
#  'could shut like telescop think could',
#  'know begin see mani way thing',
#  'happen late alic begin think',
#  'thing inde realli imposs',
#  'seem use wait littl door',
#  'go back tabl half hope might find anoth key',
#  'rate book rule shut peopl like',
#  'telescop time find littl bottl',
#  'certainli say alic round neck',
#  'bottl paper label word drink',
#  'beauti print larg letter',
#  'well say drink wise littl',
#  'alic go hurri look',
#  'first say see whether mark poison',
#  'read sever nice littl histori child',
#  'get burnt eaten wild beast unpleas',
#  'thing would rememb simpl rule',
#  'friend teach red hot poker',
#  'burn hold long cut',
#  'finger deepli knife usual bleed',
#  'never forget drink much bottl mark',
#  'poison almost certain disagre sooner',
#  'later',
#  'howev bottl mark poison alic ventur',
#  'tast find nice fact sort',
#  'mix flavour cherri tart custard pine appl roast',
#  'turkey toffe hot butter toast soon finish',
#  '',
#  '',
#  '',
#  '',
#  'curiou feel say alic must shut',
#  'like telescop',
#  'inde ten inch high',
#  'face brighten think right',
#  'size go littl door love garden',
#  'first howev wait minut see',
#  'go shrink felt littl nervou',
#  'might end know say alic',
#  'go altogeth like candl wonder',
#  'like tri fanci flame candl',
#  'like candl blow could rememb',
#  'ever see thing',
#  'find noth happen decid',
#  'go garden ala poor alic',
#  'get door find forgotten',
#  'littl golden key go back tabl',
#  'found could possibl reach could see',
#  'quit plainli glass tri best climb',
#  'one leg tabl slipperi',
#  'tire tri',
#  'poor littl thing sit cri',
#  'come use cri like say alic',
#  'rather sharpli advis leav minut',
#  'gener give good advic though',
#  'seldom follow sometim scold',
#  'sever bring tear eye rememb',
#  'tri box ear cheat game',
#  'croquet play curiou',
#  'child fond pretend two peopl',
#  'use think poor alic pretend two peopl',
#  'hardli enough leave make one respect',
#  'person',
#  'soon eye fell littl glass box lie',
#  'tabl open find small cake',
#  'word eat beauti mark currant',
#  'well eat say alic make grow larger',
#  'reach key make grow smaller creep',
#  'door either way get garden',
#  'care happen',
#  'ate littl bit say anxious',
#  'way way hold hand top head',
#  'feel way grow quit surpris',
#  'find remain size sure gener',
#  'happen one eat cake alic get much',
#  'way expect noth way thing happen',
#  'seem quit dull stupid life',
#  'common way',
#  'set work soon finish cake',
#  '',
#  '',
#  '',
#  'chapter',
#  'pool tear',
#  'curious curious cri alic much',
#  'surpris moment quit forget speak good',
#  'english open like largest telescop',
#  'ever good bye foot look',
#  'foot seem almost sight get',
#  'far poor littl foot wonder put',
#  'shoe stock dear sure',
#  'abl shall great deal far troubl',
#  'must manag best way must',
#  'kind think alic perhap walk',
#  'way want let see give new pair',
#  'boot everi christma',
#  'go plan would manag',
#  'must carrier think funni',
#  'seem send present one foot odd',
#  'direct look',
#  'alic right foot esq',
#  'hearthrug',
#  'near fender',
#  'alic love',
#  'dear nonsens talk',
#  'head strike roof hall',
#  'fact nine foot high take',
#  'littl golden key hurri garden door',
#  'poor alic much could lie one',
#  'side look garden one eye get',
#  'hopeless ever sit begin',
#  'cri',
#  'ought asham say alic great',
#  'girl like might well say cri',
#  'way stop moment tell go',
#  'shed gallon tear larg pool',
#  'round four inch deep reach half',
#  'hall',
#  'time heard littl patter foot',
#  'distanc hastili dri eye see come',
#  'white rabbit return splendidli dress',
#  'pair white kid glove one hand larg fan',
#  'come trot along great hurri mutter',
#  'come duchess duchess',
#  'savag keep wait alic felt desper',
#  'readi ask help one rabbit',
#  'come near begin low timid voic plea',
#  'sir rabbit start violent drop white kid',
#  'glove fan skurri away dark hard',
#  'could',
#  'alic take fan glove hall',
#  'hot keep fan time go talk',
#  'dear dear queer everyth day yesterday',
#  'thing go usual wonder chang',
#  'night let think get',
#  'morn almost think rememb feel littl',
#  'differ next question',
#  'world great puzzl begin',
#  'think child know age',
#  'see could chang',
#  '',
#  'sure ada say hair goe',
#  'long ringlet mine ringlet',
#  'sure mabel know sort thing',
#  'know littl besid',
#  'dear puzzl tri know',
#  'thing use know let see four time five twelv',
#  'four time six thirteen four time seven dear',
#  'shall never get twenti rate howev',
#  'multipl tabl signifi let tri geographi',
#  'london capit pari pari capit rome',
#  'rome wrong certain must',
#  'chang mabel tri say doth littl',
#  'cross hand lap say lesson',
#  'begin repeat voic sound hoar',
#  'strang word come use',
#  'doth littl crocodil',
#  'improv shine tail',
#  'pour water nile',
#  'everi golden scale',
#  'cheer seem grin',
#  'neatli spread claw',
#  'welcom littl fish',
#  'gentli smile jaw',
#  'sure right word say poor alic',
#  'eye fill tear go must mabel',
#  'shall live poki littl',
#  'hous next toy play ever',
#  'mani lesson learn make mind',
#  'mabel stay use put',
#  'head say come dear shall look',
#  'say tell first',
#  'like person come stay',
#  'till somebodi el dear cri alic',
#  'sudden burst tear wish would put head',
#  'tire alon',
#  'say look hand',
#  'surpris see put one rabbit littl',
#  'white kid glove talk do',
#  'thought must grow small got',
#  'go tabl measur find',
#  'nearli could guess two foot high',
#  'go shrink rapidli soon find',
#  'caus fan hold drop',
#  'hastili time avoid shrink away altogeth',
#  'narrow escap say alic good deal frighten',
#  'sudden chang glad find still',
#  'exist garden ran speed',
#  'back littl door ala littl door shut',
#  'littl golden key lie glass tabl',
#  'thing wors ever think poor child',
#  'never small never declar',
#  'bad',
#  'say word foot slip anoth',
#  'moment splash chin salt water first',
#  'idea somehow fall sea',
#  'case back railway say alic',
#  'seasid life come gener',
#  'conclus wherev english coast find',
#  'number bath machin sea child dig',
#  'sand wooden spade row lodg hous',
#  'behind railway station howev soon make',
#  'pool tear wept nine',
#  'foot high',
#  'wish cri much say alic swam',
#  'tri find way shall punish',
#  'suppos drown tear queer',
#  'thing sure howev everyth queer day',
#  'heard someth splash pool',
#  'littl way swam nearer make',
#  'first think must walru hippopotamu',
#  'rememb small soon make',
#  'mous slip like',
#  'would use thought alic speak',
#  'mous everyth way',
#  'think like talk rate harm',
#  'tri begin mous know way',
#  'pool tire swim mous',
#  'alic think must right way speak mous',
#  'never do thing rememb',
#  'see brother latin grammar mous mous',
#  'mous mous mous mous look rather',
#  'inquisit seem wink one littl',
#  'eye say noth',
#  'perhap understand english think alic',
#  'daresay french mous come william',
#  'conqueror knowledg histori alic',
#  'clear notion long ago anyth happen',
#  'begin est chatt first sentenc',
#  'french lesson book mous give sudden leap',
#  'water seem quiver fright beg',
#  'pardon cri alic hastili afraid hurt',
#  'poor anim feel quit forget like cat',
#  'like cat cri mous shrill passion',
#  'voic would like cat',
#  'well perhap say alic sooth tone',
#  'angri yet wish could show cat dinah',
#  'think take fanci cat could see',
#  'dear quiet thing alic go half',
#  'swam lazili pool sit pur',
#  'nice fire lick paw wash face',
#  'nice soft thing nurs capit',
#  'one catch mouse beg pardon cri alic',
#  'time mous bristl felt',
#  'certain must realli offend talk',
#  'rather',
#  'inde cri mous trembl end',
#  'tail would talk subject famili',
#  'alway hate cat nasti low vulgar thing let hear',
#  'name',
#  'inde say alic great hurri chang',
#  'subject convers fond dog',
#  'mous answer alic go eagerli',
#  'nice littl dog near hous like show',
#  'littl bright eye terrier know long curli',
#  'brown hair fetch thing throw',
#  'sit beg dinner sort thing',
#  'rememb half belong farmer',
#  'know say use worth hundr pound',
#  'say kill rat dear cri alic',
#  'sorrow tone afraid offend',
#  'mous swim away hard could',
#  'make quit commot pool go',
#  'call softli mous dear come back',
#  'talk cat dog either',
#  'like mous heard turn round swam',
#  'slowli back face quit pale passion alic',
#  'think say low trembl voic let get',
#  'shore tell histori',
#  'understand hate cat dog',
#  'high time pool get quit crowd',
#  'bird anim fall',
#  'duck dodo lori eaglet sever curiou',
#  'creatur alic lead way whole parti swam',
#  'shore',
#  'chapter iii',
#  'caucu race long tale',
#  'inde queer look parti assembl',
#  'bank bird draggl feather anim',
#  'fur cling close drip wet cross',
#  'uncomfort',
#  'first question cours get dri',
#  'consult minut seem',
#  'quit natur alic find talk familiarli',
#  'know life inde',
#  'quit long argument lori last turn sulki',
#  'would say older must know better',
#  'alic would allow without know old',
#  'lori posit refus tell age',
#  'say',
#  'last mous seem person author among',
#  'call sit listen',
#  'soon make dri enough sit larg',
#  'ring mous middl alic keep eye',
#  'anxious fix felt sure would catch bad',
#  'cold get dri soon',
#  'ahem say mous import air readi',
#  'driest thing know silenc round plea',
#  'william conqueror whose caus favour pope',
#  'soon submit english want leader',
#  'late much accustom usurp conquest edwin',
#  'morcar earl mercia northumbria',
#  'ugh say lori shiver',
#  'beg pardon say mous frown',
#  'polit speak',
#  'say lori hastili',
#  'think say mous proceed edwin',
#  'morcar earl mercia northumbria declar',
#  'even stigand patriot archbishop canterburi find',
#  'advis',
#  'find say duck',
#  'found mous repli rather crossli cours',
#  'know mean',
#  'know mean well enough find thing say',
#  'duck gener frog worm question',
#  'archbishop find',
#  'mous notic question hurriedli go',
#  'find advis edgar athel meet william',
#  'offer crown william conduct first',
#  'moder insol norman',
#  'get dear continu turn alic',
#  'spoke',
#  'wet ever say alic melancholi tone',
#  'seem dri',
#  'case say dodo solemnli rise foot',
#  'move meet adjourn immedi adopt',
#  'energet remedi',
#  'speak english say eaglet know mean',
#  'half long word believ',
#  'either eaglet bent head hide smile',
#  'bird titter audibl',
#  'go say say dodo offend tone',
#  'best thing get dri would caucu race',
#  'caucu race say alic want much',
#  'know dodo paus think somebodi',
#  'ought speak one el seem inclin say anyth',
#  'say dodo best way explain',
#  'might like tri thing winter',
#  'day tell dodo manag',
#  'first mark race cours sort circl',
#  'exact shape matter say parti',
#  'place along cours one',
#  'two three away begin run like',
#  'leave like easi know',
#  'race howev run half',
#  'hour quit dri dodo suddenli call',
#  'race crowd round pant',
#  'ask',
#  'question dodo could answer without great deal',
#  'think sat long time one finger press upon',
#  'forehead posit usual see shakespear',
#  'pictur rest wait silenc',
#  'last dodo say everybodi must',
#  'prize',
#  'give prize quit choru voic',
#  'ask',
#  'cours say dodo point alic',
#  'one finger whole parti crowd round',
#  'call confus way prize prize',
#  'alic idea despair put hand',
#  'pocket pull box comfit luckili salt',
#  'water get hand round prize',
#  'exactli one piec round',
#  'must prize know say mous',
#  'cours dodo repli grave el',
#  'get pocket go turn alic',
#  'thimbl say alic sadli',
#  'hand say dodo',
#  'crowd round dodo',
#  'solemnli present thimbl say beg accept',
#  'eleg thimbl finish short',
#  'speech cheer',
#  'alic think whole thing absurd look',
#  'grave dare laugh could',
#  'think anyth say simpli bow take thimbl',
#  'look solemn could',
#  'next thing eat comfit caus nois',
#  'confus larg bird complain could',
#  'tast small one choke pat',
#  'back howev last sat',
#  'ring beg mous tell someth',
#  'promis tell histori know say alic',
#  'hate ad whisper half',
#  'afraid would offend',
#  'mine long sad tale say mous turn',
#  'alic sigh',
#  'long tail certainli say alic look',
#  'wonder mous tail call sad',
#  'keep puzzl mous speak',
#  'idea tale someth like',
#  'furi say',
#  'mous',
#  'met',
#  'hous',
#  'let',
#  '',
#  'law',
#  'prosecut',
#  'come',
#  'take',
#  'denial',
#  'must',
#  'trial',
#  'realli',
#  'morn',
#  'noth',
#  '',
#  'say',
#  'mous',
#  'cur',
#  'trial',
#  'dear sir',
#  '',
#  'juri',
#  'judg',
#  'would',
#  'wast',
#  '',
#  'breath',
#  '',
#  'judg',
#  'juri',
#  'say',
#  'cun',
#  'old furi',
#  '',
#  'tri',
#  'whole',
#  'caus',
#  '',
#  'condemn',
#  '',
#  '',
#  'death',
#  'attend say mous alic sever',
#  'think',
#  'beg pardon say alic humbl get',
#  'fifth bend think',
#  'cri mous sharpli angrili',
#  'knot say alic alway readi make use',
#  'look anxious let help undo',
#  'shall noth sort say mous get',
#  'walk away insult talk nonsens',
#  'mean plead poor alic easili',
#  'offend know',
#  'mous growl repli',
#  'plea come back finish stori alic call',
#  'other join choru ye plea',
#  'mous shook head impati walk littl',
#  'quicker',
#  'piti stay sigh lori soon',
#  'quit sight old crab take opportun',
#  'say daughter dear let lesson',
#  'never lose temper hold tongu say',
#  'young crab littl snappishli enough tri',
#  'patienc oyster',
#  'wish dinah know say alic aloud',
#  'address nobodi particular soon fetch back',
#  'dinah might ventur ask question',
#  'say lori',
#  'alic repli eagerli alway readi talk',
#  'pet dinah cat capit one',
#  'catch mouse think wish could see',
#  'bird eat littl bird soon look',
#  '',
#  'speech caus remark sensat among parti',
#  'bird hurri one old magpi begin',
#  'wrap care remark realli must',
#  'get home night air suit throat canari',
#  'call trembl voic child come away',
#  'dear high time bed variou pretext',
#  'move alic soon leave alon',
#  'wish mention dinah say',
#  'melancholi tone nobodi seem like',
#  'sure best cat world dear dinah',
#  'wonder shall ever see poor alic',
#  'begin cri felt lone low spirit',
#  'littl howev heard littl patter',
#  'footstep distanc look eagerli half hope',
#  'mous chang mind come back',
#  'finish stori',
#  'chapter',
#  'rabbit send littl bill',
#  'white rabbit trot slowli back',
#  'look anxious go lose someth',
#  'heard mutter duchess duchess',
#  'dear paw fur whisker get',
#  'execut sure ferret ferret',
#  'drop wonder alic guess moment',
#  'look fan pair white kid glove',
#  'good naturedli begin hunt',
#  'nowher see everyth seem chang sinc',
#  'swim pool great hall glass tabl',
#  'littl door vanish complet',
#  'soon rabbit notic alic go hunt',
#  'call angri tone mari ann',
#  'run home moment fetch pair',
#  'glove fan quick alic much frighten',
#  'ran direct point without',
#  'tri explain mistak make',
#  'take housemaid say ran',
#  'surpris find',
#  'better take fan glove find',
#  'say come upon neat littl hous door',
#  'bright brass plate name rabbit',
#  'engrav upon go without knock hurri',
#  'upstair great fear lest meet real mari ann',
#  'turn hous find fan',
#  'glove',
#  'queer seem alic say go',
#  'messag rabbit suppos dinah send',
#  'messag next begin fanci sort thing',
#  'would happen miss alic come directli get readi',
#  'walk come minut nurs get see',
#  'mous get think alic go',
#  'let dinah stop hous begin order',
#  'peopl like',
#  'time find way tidi littl room',
#  'tabl window hope fan two',
#  'three pair tini white kid glove take fan',
#  'pair glove go leav room',
#  'eye fell upon littl bottl stand near look',
#  'glass label time word drink',
#  'nevertheless uncork put lip know',
#  'someth interest sure happen say',
#  'whenev eat drink anyth see',
#  'bottl hope make grow larg',
#  'realli quit tire tini littl thing',
#  'inde much sooner expect',
#  'drunk half bottl find head press',
#  'ceil stoop save neck',
#  'broken hastili put bottl say',
#  'quit enough hope grow',
#  'get door wish drunk quit',
#  'much',
#  'ala late wish go grow',
#  'grow soon kneel floor',
#  'anoth minut even room tri',
#  'effect lie one elbow door',
#  'arm curl round head still go grow',
#  'last resourc put one arm window one',
#  'foot chimney say',
#  'whatev happen becom',
#  'luckili alic littl magic bottl full',
#  'effect grow larger still uncomfort',
#  'seem sort chanc ever get',
#  'room wonder felt unhappi',
#  'much pleasant home think poor alic one',
#  'alway grow larger smaller order',
#  'mouse rabbit almost wish go',
#  'rabbit hole yet yet rather curiou know',
#  'sort life wonder happen',
#  'use read fairi tale fanci kind thing',
#  'never happen middl one',
#  'ought book write ought',
#  'grow write one grown ad',
#  'sorrow tone least room grow',
#  '',
#  'think alic shall never get older',
#  'comfort one way never old woman',
#  'alway lesson learn like',
#  'foolish alic answer',
#  'learn lesson hardli room',
#  'room lesson book',
#  'go take first one side',
#  'make quit convers altogeth',
#  'minut hear voic outsid stop listen',
#  'mari ann mari ann say voic fetch glove',
#  'moment come littl patter foot',
#  'stair alic know rabbit come look',
#  'trembl till shake hous quit forget',
#  'thousand time larg rabbit',
#  'reason afraid',
#  'present rabbit come door tri open',
#  'door open inward alic elbow press',
#  'hard attempt prove failur alic heard',
#  'say round get window',
#  'think alic wait till',
#  'fanci hear rabbit window suddenli',
#  'spread hand make snatch air',
#  'get hold anyth heard littl shriek fall',
#  'crash broken glass conclud',
#  'possibl fall cucumb frame someth',
#  'sort',
#  'next come angri voic rabbit pat pat',
#  'voic never hear sure',
#  'dig appl yer honour',
#  'dig appl inde say rabbit angrili',
#  'come help sound broken glass',
#  'tell pat window',
#  'sure arm yer honour pronounc arrum',
#  'arm goo ever saw one size',
#  'fill whole window',
#  'sure yer honour arm',
#  'well get busi rate take',
#  'away',
#  'long silenc alic could hear',
#  'whisper sure like yer',
#  'honour tell coward',
#  'last spread hand make anoth snatch',
#  'air time two littl shriek',
#  'sound broken glass number cucumb frame',
#  'must think alic wonder next',
#  'pull window wish could sure',
#  'want stay longer',
#  'wait time without hear anyth',
#  'last come rumbl littl cartwheel sound',
#  'good mani voic talk togeth make word',
#  'ladder bring one',
#  'bill get bill fetch lad put',
#  'corner tie togeth first reach half',
#  'high enough yet well enough particular',
#  'bill catch hold rope roof bear mind',
#  'loo slate come head loud',
#  'crash bill fanci',
#  'chimney nay',
#  'bill bill master say',
#  'chimney',
#  'bill get come chimney say',
#  'alic shi seem put everyth upon bill',
#  'bill place good deal fireplac',
#  'narrow sure think kick littl',
#  'drew foot far chimney could',
#  'wait till hear littl anim guess',
#  'sort scratch scrambl chimney close',
#  'say bill give one',
#  'sharp kick wait see would happen next',
#  'first thing heard gener choru goe',
#  'bill rabbit voic along catch',
#  'hedg silenc anoth confus voic hold',
#  'head brandi choke old fellow',
#  'happen tell',
#  'last come littl feebl squeak voic bill',
#  'think alic well hardli know thank',
#  'better deal fluster tell know',
#  'someth come like jack box goe',
#  'like sky rocket',
#  'old fellow say other',
#  'must burn hous say rabbit voic',
#  'alic call loud could set',
#  'dinah',
#  'dead silenc instantli alic thought',
#  'wonder next',
#  'sen take roof minut two',
#  'begin move alic heard rabbit say',
#  'barrow begin',
#  'barrow think alic long',
#  'doubt next moment shower littl pebbl come',
#  'rattl window hit face',
#  'put stop say shout',
#  'better produc anoth dead',
#  'silenc',
#  'alic notic surpris pebbl',
#  'turn littl cake lay floor bright',
#  'idea come head eat one cake',
#  'thought sure make chang size',
#  'possibl make larger must make smaller',
#  'suppos',
#  'swallow one cake delight find',
#  'begin shrink directli soon small',
#  'enough get door run hous',
#  'find quit crowd littl anim bird wait outsid',
#  'poor littl lizard bill middl hold',
#  'two guinea pig give someth bottl',
#  'make rush alic moment appear',
#  'ran hard could soon find safe',
#  'thick wood',
#  'first thing get say alic',
#  'wander wood grow right size',
#  'second thing find way love garden',
#  'think best plan',
#  'sound excel plan doubt neatli',
#  'simpli arrang difficulti',
#  'smallest idea set peer',
#  'anxious among tree littl sharp bark',
#  'head make look great hurri',
#  'enorm puppi look larg round',
#  'eye feebli stretch one paw tri touch',
#  'poor littl thing say alic coax tone tri',
#  'hard whistl terribl frighten',
#  'time think might hungri case',
#  'would like eat spite coax',
#  'hardli know pick littl bit',
#  'stick hold puppi whereupon puppi jump',
#  'air foot yelp delight',
#  'rush stick make believ worri alic',
#  'dodg behind great thistl keep run',
#  'moment appear side puppi',
#  'make anoth rush stick tumbl head heel',
#  'hurri get hold alic think',
#  'like game play cart hors expect everi',
#  'moment trampl foot run round thistl',
#  'puppi begin seri short charg',
#  'stick run littl way forward time long',
#  'way back bark hoar till last sat',
#  'good way pant tongu hang',
#  'mouth great eye half shut',
#  'seem alic good opportun make escap',
#  'set run till quit tire',
#  'breath till puppi bark sound quit faint',
#  'distanc',
#  'yet dear littl puppi say alic',
#  'leant buttercup rest fan',
#  'one leav like teach trick',
#  'much right size',
#  'dear nearli forget get grow let',
#  'see manag suppos ought eat',
#  'drink someth great question',
#  'great question certainli alic look round',
#  'flower blade grass see',
#  'anyth look like right thing eat drink',
#  'circumst larg mushroom grow near',
#  'height look',
#  'side behind occur',
#  'might well look see top',
#  'stretch tipto peep edg',
#  'mushroom eye immedi meet larg',
#  'caterpillar sit top arm fold',
#  'quietli smoke long hookah take smallest notic',
#  'anyth el',
#  'chapter',
#  'advic caterpillar',
#  'caterpillar alic look time',
#  'silenc last caterpillar take hookah',
#  'mouth address languid sleepi voic',
#  'say caterpillar',
#  'encourag open convers alic',
#  'repli rather shyli hardli know sir present',
#  'least know get morn think',
#  'must chang sever time sinc',
#  'mean say caterpillar sternli',
#  'explain',
#  'explain afraid sir say alic',
#  'see',
#  'see say caterpillar',
#  'afraid put clearli alic repli',
#  'polit understand begin',
#  'mani differ size day confus',
#  'say caterpillar',
#  'well perhap find yet say alic',
#  'turn chrysali day',
#  'know butterfli think',
#  'feel littl queer',
#  'bit say caterpillar',
#  'well perhap feel may differ say alic',
#  'know would feel queer',
#  'say caterpillar contemptu',
#  'bring back begin',
#  'convers alic felt littl irrit caterpillar',
#  'make short remark draw say',
#  'grave think ought tell first',
#  'say caterpillar',
#  'anoth puzzl question alic could',
#  'think good reason caterpillar seem',
#  'unpleas state mind turn away',
#  'come back caterpillar call someth',
#  'import say',
#  'sound promis certainli alic turn come back',
#  '',
#  'keep temper say caterpillar',
#  'say alic swallow anger well',
#  'could',
#  'say caterpillar',
#  'alic thought might well wait noth el',
#  'perhap might tell someth worth',
#  'hear minut puf away without speak',
#  'last unfold arm take hookah mouth',
#  'say think chang',
#  'afraid sir say alic rememb thing',
#  'use keep size ten minut togeth',
#  'rememb thing say caterpillar',
#  'well tri say doth littl busi bee',
#  'come differ alic repli melancholi voic',
#  'repeat old father william say caterpillar',
#  'alic fold hand begin',
#  'old father william young man say',
#  'hair becom white',
#  'yet incessantli stand head',
#  'think age right',
#  'youth father william repli son',
#  'fear might injur brain',
#  'perfectli sure none',
#  '',
#  'old say youth mention',
#  'grown uncommonli fat',
#  'yet turn back somersault door',
#  'pray reason',
#  'youth say sage shook grey lock',
#  'keep limb suppl',
#  'use ointment one shill box',
#  'allow sell coupl',
#  'old say youth jaw weak',
#  'anyth tougher suet',
#  'yet finish goo bone beak',
#  'pray manag',
#  'youth say father take law',
#  'argu case wife',
#  'muscular strength give jaw',
#  'last rest life',
#  'old say youth one would hardli suppos',
#  'eye steadi ever',
#  'yet balanc eel end nose',
#  'make aw clever',
#  'answer three question enough',
#  'say father give air',
#  'think listen day stuff',
#  'kick stair',
#  'say right say caterpillar',
#  'quit right afraid say alic timidli',
#  'word get alter',
#  'wrong begin end say caterpillar',
#  'decidedli silenc minut',
#  'caterpillar first speak',
#  'size want ask',
#  'particular size alic hastili repli',
#  'one like chang often know',
#  'know say caterpillar',
#  'alic say noth never much contradict',
#  'life felt lose temper',
#  'content say caterpillar',
#  'well like littl larger sir',
#  'mind say alic three inch wretch',
#  'height',
#  'good height inde say caterpillar',
#  'angrili rear upright spoke exactli three',
#  'inch high',
#  'use plead poor alic piteou tone',
#  'think wish creatur',
#  'easili offend',
#  'get use time say caterpillar',
#  'put hookah mouth begin smoke',
#  'time alic wait patient choose speak',
#  'minut two caterpillar take hookah',
#  'mouth yawn twice shake get',
#  'mushroom crawl away grass mere',
#  'remark go one side make grow taller',
#  'side make grow shorter',
#  'one side side think alic',
#  '',
#  'mushroom say caterpillar',
#  'ask aloud anoth moment sight',
#  'alic remain look thought mushroom',
#  'minut tri make two side',
#  'perfectli round find difficult question',
#  'howev last stretch arm round far',
#  'would break bit edg hand',
#  'say nibbl',
#  'littl right hand bit tri effect next moment',
#  'felt violent blow underneath chin strike',
#  'foot',
#  'good deal frighten sudden chang',
#  'felt time lose shrink',
#  'rapidli set work eat bit',
#  'chin press close foot',
#  'hardli room open mouth last',
#  'manag swallow morsel lefthand bit',
#  '',
#  '',
#  '',
#  'come head free last say alic tone',
#  'delight chang alarm anoth moment',
#  'find shoulder nowher find could',
#  'see look immens length neck',
#  'seem rise like stalk sea green leav lay',
#  'far',
#  'green stuff say alic',
#  'shoulder get poor hand',
#  'see move speak',
#  'result seem follow except littl shake among',
#  'distant green leav',
#  'seem chanc get hand',
#  'head tri get head delight',
#  'find neck would bend easili direct',
#  'like serpent succeed curv',
#  'grace zigzag go dive among leav',
#  'find noth top tree',
#  'wander sharp hiss make draw back',
#  'hurri larg pigeon flown face beat',
#  'violent wing',
#  ...]

# %%
import collections
counter = collections.Counter()
for line in lines:
    for word in nltk.word_tokenize(line):
        counter[word.lower()]+=1
        
word2idx = {w:(i+1) for i,(w,_) in enumerate(counter.most_common())}
idx2word = {v:k for k,v in word2idx.items()}

# %%
xs = []
ys = []
for line in lines:
    embedding = [word2idx[w.lower()] for w in nltk.word_tokenize(line)]
    triples = list(nltk.trigrams(embedding))
    w_lefts = [x[0] for x in triples]
    w_centers = [x[1] for x in triples]
    w_rights = [x[2] for x in triples]
    xs.extend(w_centers)
    ys.extend(w_lefts)
    xs.extend(w_centers)
    ys.extend(w_rights)

# %%
print (len(word2idx))

vocab_size = len(word2idx)+1
print(vocab_size)
# Out:
# 1786
# 1787

# %%
ohe = OneHotEncoder(categories=[range(vocab_size)])
X = ohe.fit_transform(np.array(xs).reshape(-1, 1)).todense()
Y = ohe.fit_transform(np.array(ys).reshape(-1, 1)).todense()
Xtrain, Xtest, Ytrain, Ytest,xstr,xsts = train_test_split(X, Y,xs, test_size=0.3, random_state=42)
print(Xtrain.shape, Xtest.shape, Ytrain.shape, Ytest.shape)
# Out:
# (9707, 1787) (4161, 1787) (9707, 1787) (4161, 1787)

# %%
from keras.layers import Input,Dense,Dropout
from keras.models import Model
np.random.seed(42)
BATCH_SIZE = 128
NUM_EPOCHS = 20
input_layer = Input(shape = (Xtrain.shape[1],),name="input")
first_layer = Dense(300,activation='relu',name = "first")(input_layer)
first_dropout = Dropout(0.5,name="firstdout")(first_layer)
second_layer = Dense(2,activation='relu',name="second")(first_dropout)
third_layer = Dense(300,activation='relu',name="third")(second_layer)
third_dropout = Dropout(0.5,name="thirdout")(third_layer)
fourth_layer = Dense(Ytrain.shape[1],activation='softmax',name = "fourth")(third_dropout)
history = Model(input_layer,fourth_layer)
history.compile(optimizer = "rmsprop",loss="categorical_crossentropy",metrics=["accuracy"])

# %%
history.fit(Xtrain, Ytrain, batch_size=BATCH_SIZE,epochs=NUM_EPOCHS, verbose=1,validation_split = 0.2)
# Out:
# Epoch 1/20
# 61/61 [==============================] - 1s 15ms/step - loss: 6.9150 - accuracy: 0.0415 - val_loss: 6.4260 - val_accuracy: 0.0479
# Epoch 2/20
# 61/61 [==============================] - 1s 13ms/step - loss: 6.3954 - accuracy: 0.0437 - val_loss: 6.4413 - val_accuracy: 0.0479
# Epoch 3/20
# 61/61 [==============================] - 1s 13ms/step - loss: 6.3489 - accuracy: 0.0437 - val_loss: 6.4708 - val_accuracy: 0.0479
# Epoch 4/20
# 61/61 [==============================] - 1s 13ms/step - loss: 6.3245 - accuracy: 0.0446 - val_loss: 6.4981 - val_accuracy: 0.0479
# Epoch 5/20
# 61/61 [==============================] - 1s 13ms/step - loss: 6.3091 - accuracy: 0.0448 - val_loss: 6.5297 - val_accuracy: 0.0479
# Epoch 6/20
# 61/61 [==============================] - 1s 13ms/step - loss: 6.2940 - accuracy: 0.0467 - val_loss: 6.5455 - val_accuracy: 0.0561
# Epoch 7/20
# 61/61 [==============================] - 1s 13ms/step - loss: 6.2776 - accuracy: 0.0505 - val_loss: 6.5489 - val_accuracy: 0.0561
# Epoch 8/20
# 61/61 [==============================] - 1s 13ms/step - loss: 6.2637 - accuracy: 0.0524 - val_loss: 6.5587 - val_accuracy: 0.0566
# Epoch 9/20
# 61/61 [==============================] - 1s 14ms/step - loss: 6.2456 - accuracy: 0.0545 - val_loss: 6.5506 - val_accuracy: 0.0582
# Epoch 10/20
# 61/61 [==============================] - 1s 16ms/step - loss: 6.2268 - accuracy: 0.0540 - val_loss: 6.5587 - val_accuracy: 0.0613
# Epoch 11/20
# 61/61 [==============================] - 1s 17ms/step - loss: 6.2088 - accuracy: 0.0540 - val_loss: 6.5612 - val_accuracy: 0.0623
# Epoch 12/20
# 61/61 [==============================] - 1s 14ms/step - loss: 6.1910 - accuracy: 0.0546 - val_loss: 6.6071 - val_accuracy: 0.0608
# Epoch 13/20
# 61/61 [==============================] - 1s 14ms/step - loss: 6.1705 - accuracy: 0.0563 - val_loss: 6.5702 - val_accuracy: 0.0623
# Epoch 14/20
# 61/61 [==============================] - 1s 13ms/step - loss: 6.1557 - accuracy: 0.0568 - val_loss: 6.5737 - val_accuracy: 0.0587
# Epoch 15/20
# 61/61 [==============================] - 1s 13ms/step - loss: 6.1381 - accuracy: 0.0561 - val_loss: 6.5739 - val_accuracy: 0.0597
# Epoch 16/20
# 61/61 [==============================] - 1s 13ms/step - loss: 6.1170 - accuracy: 0.0554 - val_loss: 6.5722 - val_accuracy: 0.0597
# Epoch 17/20
# 61/61 [==============================] - 1s 13ms/step - loss: 6.1082 - accuracy: 0.0577 - val_loss: 6.6024 - val_accuracy: 0.0587
# Epoch 18/20
# 61/61 [==============================] - 1s 13ms/step - loss: 6.0938 - accuracy: 0.0567 - val_loss: 6.5967 - val_accuracy: 0.0582
# Epoch 19/20
# 61/61 [==============================] - 1s 13ms/step - loss: 6.0822 - accuracy: 0.0568 - val_loss: 6.6280 - val_accuracy: 0.0587
# Epoch 20/20
# 61/61 [==============================] - 1s 13ms/step - loss: 6.0703 - accuracy: 0.0571 - val_loss: 6.6434 - val_accuracy: 0.0608

# %%
# 잠재 변수 예측을 위해 모델의 인코더 부분 추출
encoder = Model(history.input,history.get_layer("second").output)

# 추출된 인코더 모델을 사용해 잠재 변수 예측
reduced_X = encoder.predict(Xtest)

# 더 나은 표현을 위해 출력을 Pandas 데이터 프레임 구조로 변환
final_pdframe = pd.DataFrame(reduced_X)
final_pdframe.columns = ["xaxis","yaxis"]
final_pdframe["word_indx"] = xsts
final_pdframe["word"] = final_pdframe["word_indx"].map(idx2word)

# %%
# rows = random.sample(final_pdframe.index, 100) // error
rows = random.sample(list(final_pdframe.index), 100)

# vis_df = final_pdframe.ix[rows] // error
vis_df = final_pdframe.loc[rows] # 2
labels = list(vis_df["word"])
xvals = list(vis_df["xaxis"])
yvals = list(vis_df["yaxis"])

# %%
# 인치 단위
plt.figure(figsize=(10, 10))
for i, label in enumerate(labels):
    x = xvals[i]
    y = yvals[i]
    plt.scatter(x, y)
    plt.annotate(label,xy=(x, y),xytext=(5, 2),textcoords='offset points', ha='right',va='bottom')
plt.xlabel("Dimension 1")
plt.ylabel("Dimension 2")
plt.show()
